# %%
# External libraries
import numpy as np
import time
import matplotlib.pyplot as plt
import matplotlib.style as style
import pandas as pd
import astropy
import scipy
from filterpy.kalman import KalmanFilter 
from filterpy.common import Q_discrete_white_noise
from scipy.linalg import block_diag
from astropy import units as u
from poliastro.bodies import Earth, Mars, Sun, Moon
from poliastro.twobody import Orbit
from poliastro.plotting import OrbitPlotter2D
from poliastro.plotting import OrbitPlotter3D
from sklearn import linear_model, datasets
import glob
# Own Libraries
from utility.utils import *
from KalmanFilter.kf import *
from Detect.detector import *
from Match.pair import *
from Match.icp import *

style.use('seaborn-paper')
# %matplotlib tk

global km2px, deg2km, px2km, deg2px

def find_pos(idx):
    # Loading All Images:
    dict = load_all_images(dt=10)
    # Img:
    filename = dict[str(idx+1)]
    img=cv2.imread(filename)
    # Detection:
    t1 = time.time()
    craters_det = detect(img)
    # Removing minor craters:
    craters_det = craters_det[craters_det[:,2] > 15]
    t2 = time.time()
    print(f'Detection Time:{t2-t1:.2f}\n')
    # Pandas DataFrame:
    df_craters_det = sort_mat(craters_det)
    # Find all triplets:
    t1 = time.time()
    triplets = find_all_triplets(craters_det)
    triplets_det= pd.DataFrame(triplets, columns=['Angle1','Angle2','Angle3','des1','des2','des3','x1','y1','r1','x2','y2','r2','x3',   'y3','r3'])
    triplets_det.shape
    t2 = time.time()
    print('\n')
    print(f'Total craters founded:{craters_det.shape[0]}')
    print(f'Number of total combinations:{triplets_det.shape[0]}\nComputational time: {t2-t1:.2f} s')

###############################################################################################################
    # Opening Database:
    DB = pd.read_csv('DATA/H_L_combined.csv')
    # DB = pd.read_csv('DATA/lunar_crater_database_robbins_2018.csv')

    # Filtering DATABASE:
    MULTIPLAYER = 1.
    span = 3.29/2   *MULTIPLAYER # TODO: Aggiustare l'immagine di catalogo a grandezza effettiva!
    lat_bounds=[-span, span]
    get_lon = float(filename.split('_')[-1].split('jpg')[0][:-2])
    lon_bounds=[get_lon-span,get_lon+span]
    craters_cat = CatalogSearch(DB, lat_bounds, lon_bounds, CAT_NAME='COMBINED')
    # craters_cat = CatalogSearch(DB, lat_bounds, lon_bounds, CAT_NAME='ROBBINS')

    # FIND TRIPLETS:
    if craters_cat is not None:
        km2deg = 1/deg2km
        craters_cat = craters_cat[(craters_cat.Diam < 35)&(craters_cat.Diam > 4)]
        craters_cat['Diam']*=0.5*km2deg # km --- > deg

        craters_cat_m = np.array(craters_cat)
        t1 = time.time()
        triplets_cat_m = find_all_triplets(craters_cat_m)
        triplets_cat = pd.DataFrame(triplets_cat_m, columns=['Angle1','Angle2','Angle3','des1','des2','des3','lon1','lat1', 'r1','lon2',    'lat2','r2','lon3','lat3','r3'])
        triplets_cat['r1'] *= deg2km
        triplets_cat['r2'] *= deg2km
        triplets_cat['r3'] *= deg2km
        t2 = time.time()
        print(f'Total craters catalogued:{craters_cat.shape[0]+1}')
        print(f'Number of total combinations:{triplets_cat.shape[0]}\nComputational time: {t2-t1:.2f} s')
    else:
        print('No craters in cat!')
###############################################################################################################
    tol1 = 7.

    t1 = time.time()
    QUERY1 = triplets_cat
    QUERY2 = triplets_det
    QUERY1 = dropduplicates(QUERY1)
    QUERY2 = dropduplicates(QUERY2) 

    if QUERY1.shape[0]<QUERY2.shape[0]:
        mode = 'natural'
        joins, items = inner_join(QUERY1, QUERY2, tol1)
    else:
        mode = 'inverse'
        joins, items = inner_join(QUERY2, QUERY1, tol1)
    print(f'Mode:{ mode}')
    t2 = time.time()
    print(f'Computational time: {t2-t1:.2f} s\nPossible list Combinations: {len(items)}')
###############################################################################################################
    t1 = time.time()
    tol2 = 1.
    S, iss = [], []
    for i in range(len(joins)):
        join = joins[i]
        des1, des2, des3 = items[i].des1, items[i].des2, items[i].des3
        s=join[ (abs(join.des1 - des1) < tol2) & (abs(join.des2 - des2) < tol2) & (abs(join.des3 - des3) < tol2)\
              | (abs(join.des1 - des2) < tol2) & (abs(join.des2 - des3) < tol2) & (abs(join.des3 - des1) < tol2)\
              | (abs(join.des1 - des3) < tol2) & (abs(join.des2 - des1) < tol2) & (abs(join.des3 - des2) < tol2)]

        if s.shape[0] > 0:
            S.append(s)
            iss.append(items[i])
    t2 = time.time()
    print(f'Computational time: {t2-t1:.2f} s\nPossible list Combinations: {len(S)}')
###############################################################################################################
    # FIND TRUE COMBINATIONS:
    CAMx, CAMy = ( (lon_bounds[0] + lon_bounds[1]) / 2, (lat_bounds[0] + lat_bounds[1]) / 2) # Location Absolute

    Is, Js = [], []
    for I in range(len(iss)):
        row1 = iss[I]
        for J in range(S[I].shape[0]):
            if check_sol(I,J, 0.1, mode, S, iss) & check_sol2(I,J, 0.14, mode, S, iss, CAMx, CAMy): # TODO: Aggiungere checksol3:   confronto crts
                    Is.append(I)
                    Js.append(J)
                    print(I,J)
    Is = np.array(Is)
    Js = np.array(Js)
###############################################################################################################
    if len(Js)!=0:    

        H, px2deg = H_estimation(Is, Js, mode, S, iss, CAMx, CAMy)
        print(f'Height: {H:.2f}          px2deg: {px2deg:.5f}')

        LON, LAT = [], []
        for s in range(len(Is)):
            i, j = Is[s], Js[s]
            A,B,B_a = find_ABBa(i,j,mode, S, iss, CAMx, CAMy)

            Lon, Lat = LL_estimation(A, B, B_a, px2deg)
            LON.append(Lon)
            LAT.append(Lat)
        if len(LON)>3:
            LON_m = np.mean(filter_quartile(LON))
            LAT_m = np.mean(filter_quartile(LAT))
        else:
            LON_m = np.mean(LON)
            LAT_m = np.mean(LAT)

        print(f'LON: {LON_m:.3f}       LAT:{LAT_m:.3f}')
    else: print('Association was not possible...')
###############################################################################################################
#                                                    READ REAL DATA:
###############################################################################################################
    dt = 10
    df = pd.read_csv(f'DATA/ephemeris sat/inclination zero/{dt} step size.csv', header=3, sep=';') 
    real_Latitudes, real_Longitudes, real_Altitudes = df['Lat (deg)'], df['Lon (deg)'], df['Alt (km)']
    real_Vxs,real_Vys,real_Vzs = df['x (km/sec)'], df['y (km/sec)'],df['z (km/sec)']

    real_X, real_Y, real_Z = [], [], []
    for i in range(len(df)):
        altitude = real_Altitudes[i]
        latitude = real_Latitudes[i]
        longitude = real_Longitudes[i]
        x, y, z = spherical2cartesian(altitude, latitude, longitude)
        real_X.append(x)
        real_Y.append(y)
        real_Z.append(z)
    real_X, real_Y, real_Z = np.array(real_X),np.array(real_Y),np.array(real_Z)
#############################################################################################################################

    Error = []
    if len(Js)!=0: 
        TRUE_POS = np.array([real_Longitudes[idx], real_Latitudes[idx]])
        # print(TRUE_POS)
        D = TRUE_POS - np.array([LON_m,LAT_m])
        ERROR_LL = D*deg2km
        Error.append(H-50)
        Error.append(ERROR_LL[0])
        Error.append(ERROR_LL[1])
        print(f'Error (km)| H: {Error[0]:.2f}Km    Lon:{Error[1]:.2f}Km    Lat:{Error[2]:.2f}Km')

        x,y,z = spherical2cartesian(H, LAT_m, LON_m)
        x,y,z = x*1000, y*1000, z*1000 # Km ---> m

        xEast, yNorth, zUp = ecef_to_enu(x, y, z, real_Latitudes[idx], real_Longitudes[idx], real_Altitudes[idx]*1000)
        print(f'ENU frame| xEast: {xEast:.2f}m    yNorth:{yNorth:.2f}m    zUp:{zUp:.2f}m')

    else: print('Association was not possible...')

    if len(Js)!=0: 
        Position_est = np.array([H, LAT_m, LON_m])
        Error_est = np.array([abs(Error[0]),abs(Error[1]),abs(Error[2])])
        ENU = np.array([abs(xEast),abs(yNorth),abs(zUp)])
        return Position_est, Error_est, ENU
    else:
        return None
# Out:
# WARNING:tensorflow:From /home/sirbastiano/anaconda3/envs/crateri/lib/python3.6/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1635: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %%
FILE = pd.DataFrame(columns=['ID','H','LAT','LON','Error_H(km)','Error_LAT(km)','Error_LON(km)','xEast','yNorth','zUp'])

# a = np.linspace(0,615,616).astype('int')
# b = np.linspace(624,678,678-624+1).astype('int')
# indexes = np.hstack([a,b])


for i in range(678):
    try:
        # Missing images compensation:
        if i > 615 & i < 624:
            print('Sorry, skipping this image..')
            new_row = {'ID':i, 'H':np.NaN, 'LAT':np.NaN,'LON':np.NaN,'Error_H(km)':np.NaN,'Error_LAT(km)':np.NaN,\
                    'Error_LON(km)':np.NaN, 'xEast':np.NaN,'yNorth':np.NaN,'zUp':np.NaN}
            FILE = FILE.append(new_row, ignore_index=True)
            FILE.to_csv('Pos_Err_d100_quartile_40-60_HL.csv')

        else:
            pos , err, ENU = find_pos(i)
            new_row = {'ID':i, 'H':pos[0], 'LAT':pos[1],'LON':pos[2],'Error_H(km)':err[0],'Error_LAT(km)':err[1],\
                    'Error_LON(km)':err[2], 'xEast':ENU[0],'yNorth':ENU[1],'zUp':ENU[2]}
            FILE = FILE.append(new_row, ignore_index=True)
            FILE.to_csv('Pos_Err_d100_quartile_40-60_HL.csv')

    except TypeError: 
        print('Sorry, cannot find matches...')
        new_row = {'ID':i, 'H':np.NaN, 'LAT':np.NaN,'LON':np.NaN,'Error_H(km)':np.NaN,'Error_LAT(km)':np.NaN,\
                    'Error_LON(km)':np.NaN, 'xEast':np.NaN,'yNorth':np.NaN,'zUp':np.NaN}
        FILE = FILE.append(new_row, ignore_index=True)
        FILE.to_csv('Pos_Err_d100_quartile_40-60_HL.csv')

    except UnboundLocalError: 
        print('Sorry, no crater in catalog..')
        new_row = {'ID':i, 'H':np.NaN, 'LAT':np.NaN,'LON':np.NaN,'Error_H(km)':np.NaN,'Error_LAT(km)':np.NaN,\
                    'Error_LON(km)':np.NaN, 'xEast':np.NaN,'yNorth':np.NaN,'zUp':np.NaN}
        FILE = FILE.append(new_row, ignore_index=True)
        FILE.to_csv('Pos_Err_d100_quartile_40-60_HL.csv')

    except NameError: 
        print('Sorry, skipping this image..')
        new_row = {'ID':i, 'H':np.NaN, 'LAT':np.NaN,'LON':np.NaN,'Error_H(km)':np.NaN,'Error_LAT(km)':np.NaN,\
                    'Error_LON(km)':np.NaN, 'xEast':np.NaN,'yNorth':np.NaN,'zUp':np.NaN}
        FILE = FILE.append(new_row, ignore_index=True)
        FILE.to_csv('Pos_Err_d100_quartile_40-60_HL.csv')

print('Done!')
# Out:
# nal time: 0.42 s
# Possible list Combinations: 28
# 1 0
# 10 0
# Height: 53.32          px2deg: 0.00414
# LON: -160.355       LAT:-0.005
# Error (km)| H: 3.32Km    Lon:1.42Km    Lat:0.12Km
# ENU frame| xEast: -1463.19m    yNorth:-123.16m    zUp:3318.83m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:16
# Number of total combinations:3360
# Computational time: 0.05 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:12
# Number of total combinations:990
# Computational time: 0.02 s
# Mode:natural
# Computational time: 1.01 s
# Possible list Combinations: 165
# Computational time: 0.58 s
# Possible list Combinations: 58
# 1 0
# 2 0
# 3 1
# 12 0
# 14 0
# 17 0
# 24 0
# 25 0
# 26 1
# 27 0
# 28 0
# 30 0
# 31 0
# 34 0
# 36 0
# 40 0
# 41 0
# 42 0
# 43 0
# 50 0
# 51 0
# Height: 50.57          px2deg: 0.00393
# LON: -159.796       LAT:0.007
# Error (km)| H: 0.57Km    Lon:0.53Km    Lat:-0.24Km
# ENU frame| xEast: -549.22m    yNorth:245.70m    zUp:567.06m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:20
# Number of total combinations:6840
# Computational time: 0.10 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:14
# Number of total combinations:1716
# Computational time: 0.03 s
# Mode:natural
# Computational time: 1.81 s
# Possible list Combinations: 286
# Computational time: 1.02 s
# Possible list Combinations: 129
# 3 0
# 4 0
# 5 0
# 12 1
# 17 0
# 18 0
# 20 2
# 21 0
# 22 0
# 25 0
# 27 0
# 28 0
# 35 0
# 37 0
# 38 0
# 43 0
# 44 0
# 45 0
# 47 0
# 48 0
# 56 0
# 64 0
# 69 0
# 70 0
# 74 0
# 75 0
# 77 0
# 79 0
# 80 0
# 81 0
# 91 1
# 95 1
# 102 0
# 105 0
# 108 0
# 119 0
# Height: 50.33          px2deg: 0.00391
# LON: -159.258       LAT:0.004
# Error (km)| H: 0.33Km    Lon:0.27Km    Lat:-0.14Km
# ENU frame| xEast: -278.71m    yNorth:141.69m    zUp:330.72m
# Detection Time:0.46
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:23
# Number of total combinations:10626
# Computational time: 0.16 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:17
# Number of total combinations:3360
# Computational time: 0.06 s
# Mode:natural
# Computational time: 3.54 s
# Possible list Combinations: 560
# Computational time: 1.98 s
# Possible list Combinations: 255
# 10 0
# 12 0
# 13 0
# 14 1
# 21 1
# 25 0
# 27 0
# 28 2
# 29 0
# 30 0
# 34 0
# 36 0
# 37 0
# 40 0
# 41 0
# 42 0
# 51 0
# 58 0
# 60 0
# 61 1
# 62 0
# 66 0
# 68 0
# 72 0
# 77 0
# 78 1
# 79 0
# 80 0
# 82 0
# 83 0
# 85 0
# 86 0
# 90 0
# 93 0
# 97 0
# 101 0
# 102 0
# 112 2
# 129 0
# 132 0
# 136 0
# 148 0
# 149 0
# 151 0
# 154 0
# 159 1
# 161 0
# 161 1
# 168 2
# 191 0
# 192 0
# 193 0
# 194 0
# 196 0
# 198 0
# 203 1
# 203 3
# 204 0
# 206 0
# 209 0
# 210 0
# 211 0
# 215 0
# 216 1
# 217 1
# 220 0
# 227 1
# 230 1
# 234 0
# 243 0
# 250 0
# Height: 50.33          px2deg: 0.00391
# LON: -158.725       LAT:0.001
# Error (km)| H: 0.33Km    Lon:0.18Km    Lat:-0.06Km
# ENU frame| xEast: -185.34m    yNorth:63.88m    zUp:329.96m
# Detection Time:0.46
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:22
# Number of total combinations:9240
# Computational time: 0.14 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:18
# Number of total combinations:4080
# Computational time: 0.07 s
# Mode:natural
# Computational time: 4.29 s
# Possible list Combinations: 680
# Computational time: 2.39 s
# Possible list Combinations: 356
# 16 0
# 17 0
# 22 0
# 23 0
# 24 0
# 25 0
# 25 1
# 26 0
# 28 2
# 29 0
# 30 0
# 32 0
# 33 0
# 34 0
# 35 0
# 36 0
# 37 0
# 38 0
# 39 1
# 41 0
# 42 0
# 47 1
# 49 0
# 50 0
# 51 0
# 55 1
# 56 0
# 61 0
# 76 0
# 77 0
# 80 0
# 81 0
# 82 1
# 82 2
# 83 0
# 83 1
# 84 0
# 85 0
# 88 0
# 89 0
# 90 0
# 91 0
# 97 0
# 101 0
# 108 0
# 109 0
# 112 2
# 113 0
# 117 0
# 118 0
# 119 0
# 125 0
# 161 0
# 165 0
# 169 0
# 173 0
# 185 0
# 188 0
# 199 1
# 204 0
# 213 1
# 214 0
# 217 0
# 226 1
# 227 1
# 229 1
# 233 0
# 234 2
# 234 3
# 236 0
# 238 0
# 242 0
# 243 0
# 244 0
# 246 0
# 247 0
# 248 1
# 251 0
# 257 0
# 259 0
# 260 0
# 261 2
# 262 0
# 265 1
# 265 2
# 266 2
# 267 2
# 270 0
# 276 0
# 277 1
# 279 0
# 280 0
# 283 1
# 286 0
# 302 0
# 303 0
# 305 0
# 306 0
# 307 1
# 312 0
# 314 0
# 315 0
# 318 0
# 321 1
# 322 0
# 323 1
# 326 0
# 328 0
# 329 0
# 330 0
# 331 0
# 345 0
# 346 3
# 347 0
# 350 0
# Height: 50.47          px2deg: 0.00392
# LON: -158.201       LAT:0.009
# Error (km)| H: 0.47Km    Lon:0.34Km    Lat:-0.30Km
# ENU frame| xEast: -346.92m    yNorth:311.90m    zUp:465.97m
# Detection Time:0.47
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:22
# Number of total combinations:9240
# Computational time: 0.14 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:19
# Number of total combinations:4896
# Computational time: 0.08 s
# Mode:natural
# Computational time: 5.14 s
# Possible list Combinations: 816
# Computational time: 2.84 s
# Possible list Combinations: 478
# 0 1
# 7 1
# 8 1
# 9 1
# 16 0
# 18 2
# 19 0
# 57 0
# 60 5
# 61 0
# 63 0
# 64 0
# 65 0
# 66 0
# 67 2
# 70 1
# 72 0
# 74 0
# 75 0
# 76 0
# 79 1
# 80 0
# 81 0
# 85 2
# 87 0
# 90 1
# 91 0
# 92 2
# 97 0
# 98 1
# 99 3
# 102 0
# 103 0
# 108 0
# 109 0
# 110 0
# 111 0
# 112 0
# 115 1
# 119 1
# 120 0
# 129 2
# 135 0
# 136 1
# 159 2
# 160 2
# 164 0
# 165 0
# 166 0
# 169 1
# 172 0
# 181 0
# 189 0
# 205 0
# 207 2
# 210 0
# 224 1
# 229 0
# 234 2
# 237 0
# 238 1
# 239 1
# 240 0
# 242 0
# 243 1
# 244 0
# 247 1
# 251 1
# 252 2
# 263 2
# 269 0
# 270 2
# 275 1
# 277 0
# 280 0
# 281 1
# 282 0
# 284 1
# 285 1
# 288 0
# 290 1
# 292 0
# 296 1
# 297 0
# 299 0
# 300 1
# 303 2
# 311 0
# 313 1
# 315 0
# 317 0
# 319 0
# 321 2
# 322 1
# 323 0
# 326 0
# 327 0
# 334 1
# 335 1
# 338 0
# 347 0
# 349 0
# 350 0
# 351 0
# 352 0
# 355 1
# 356 1
# 359 0
# 368 0
# 369 4
# 371 0
# 372 0
# 374 1
# 378 0
# 379 1
# 382 0
# 383 0
# 385 1
# 386 2
# 387 0
# 389 2
# 392 0
# 396 0
# 397 0
# 409 0
# 427 0
# 429 0
# 429 2
# 430 0
# 432 0
# 433 0
# 434 2
# 438 0
# 440 0
# 442 1
# 445 0
# 449 1
# 450 0
# 451 1
# 455 0
# 458 0
# 459 0
# 460 0
# 461 0
# 470 0
# 475 0
# Height: 50.16          px2deg: 0.00390
# LON: -157.664       LAT:0.007
# Error (km)| H: 0.16Km    Lon:0.13Km    Lat:-0.24Km
# ENU frame| xEast: -135.48m    yNorth:243.08m    zUp:157.58m
# Detection Time:0.48
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:20
# Number of total combinations:6840
# Computational time: 0.11 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:19
# Number of total combinations:4896
# Computational time: 0.08 s
# Mode:natural
# Computational time: 5.11 s
# Possible list Combinations: 816
# Computational time: 3.00 s
# Possible list Combinations: 480
# 6 0
# 7 3
# 9 1
# 10 1
# 16 0
# 19 0
# 22 0
# 68 3
# 73 0
# 80 0
# 81 0
# 83 0
# 85 0
# 91 1
# 94 0
# 95 0
# 96 2
# 97 1
# 101 0
# 103 3
# 106 0
# 110 1
# 113 0
# 114 0
# 119 0
# 120 0
# 124 0
# 127 2
# 132 1
# 133 2
# 148 0
# 152 2
# 161 0
# 163 0
# 166 0
# 170 0
# 171 0
# 172 0
# 179 0
# 188 1
# 203 1
# 205 0
# 216 1
# 237 1
# 238 0
# 239 0
# 243 0
# 245 1
# 263 0
# 264 1
# 266 2
# 268 1
# 270 1
# 272 0
# 275 1
# 282 0
# 287 0
# 289 0
# 291 0
# 297 0
# 298 0
# 301 1
# 303 0
# 304 2
# 315 0
# 318 0
# 320 0
# 323 0
# 330 0
# 332 0
# 334 0
# 339 2
# 341 1
# 350 0
# 352 0
# 355 1
# 359 0
# 366 2
# 367 0
# 377 0
# 378 0
# 381 1
# 383 1
# 384 0
# 385 0
# 388 1
# 393 0
# 395 0
# 401 0
# 411 0
# 430 0
# 431 0
# 433 0
# 434 1
# 438 0
# 444 0
# 449 0
# 451 0
# 457 0
# 459 0
# 460 0
# 468 0
# Height: 50.09          px2deg: 0.00389
# LON: -157.135       LAT:0.005
# Error (km)| H: 0.09Km    Lon:0.15Km    Lat:-0.16Km
# ENU frame| xEast: -152.51m    yNorth:161.97m    zUp:94.22m
# Detection Time:0.46
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:21
# Number of total combinations:7980
# Computational time: 0.13 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:17
# Number of total combinations:3360
# Computational time: 0.06 s
# Mode:natural
# Computational time: 3.56 s
# Possible list Combinations: 560
# Computational time: 2.02 s
# Possible list Combinations: 336
# 0 0
# 3 0
# 4 1
# 11 0
# 12 0
# 14 0
# 56 0
# 57 0
# 59 0
# 60 0
# 65 1
# 75 1
# 76 2
# 80 0
# 84 2
# 89 0
# 90 0
# 113 0
# 114 0
# 116 0
# 121 1
# 127 2
# 173 0
# 174 0
# 181 0
# 182 0
# 184 2
# 191 2
# 194 0
# 201 0
# 214 1
# 216 1
# 217 3
# 223 1
# 224 0
# 229 2
# 230 0
# 240 0
# 251 0
# 256 1
# 257 0
# 269 0
# 287 0
# 288 0
# 291 0
# 292 0
# 293 0
# 324 0
# 328 2
# Height: 49.95          px2deg: 0.00388
# LON: -156.609       LAT:0.003
# Error (km)| H: -0.05Km    Lon:0.25Km    Lat:-0.10Km
# ENU frame| xEast: -256.95m    yNorth:102.76m    zUp:-54.13m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:15
# Number of total combinations:2730
# Computational time: 0.04 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:16
# Number of total combinations:2730
# Computational time: 0.04 s
# Mode:inverse
# Computational time: 2.87 s
# Possible list Combinations: 455
# Computational time: 1.67 s
# Possible list Combinations: 149
# 0 0
# 1 0
# 3 0
# 5 0
# 6 0
# 7 1
# 8 0
# 9 0
# 10 0
# 13 0
# 14 0
# 17 0
# 20 0
# 26 0
# 27 0
# 28 0
# 31 0
# 37 2
# 40 1
# 41 0
# 45 0
# 56 0
# 58 0
# 92 1
# 93 0
# 103 0
# 110 0
# 129 2
# 145 0
# Height: 51.36          px2deg: 0.00399
# LON: -156.038       LAT:0.031
# Error (km)| H: 1.36Km    Lon:-0.98Km    Lat:-0.97Km
# ENU frame| xEast: 1010.79m    yNorth:999.96m    zUp:1356.15m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:15
# Number of total combinations:2730
# Computational time: 0.05 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:14
# Number of total combinations:1716
# Computational time: 0.03 s
# Mode:natural
# Computational time: 1.83 s
# Possible list Combinations: 286
# Computational time: 1.01 s
# Possible list Combinations: 64
# 5 0
# 8 0
# 9 0
# 9 1
# 10 0
# 11 1
# 46 0
# 47 0
# 50 0
# 54 0
# 58 0
# Height: 50.18          px2deg: 0.00390
# LON: -155.545       LAT:0.010
# Error (km)| H: 0.18Km    Lon:0.13Km    Lat:-0.32Km
# ENU frame| xEast: -129.56m    yNorth:330.03m    zUp:178.59m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:15
# Number of total combinations:2730
# Computational time: 0.04 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:12
# Number of total combinations:990
# Computational time: 0.02 s
# Mode:natural
# Computational time: 1.04 s
# Possible list Combinations: 165
# Computational time: 0.58 s
# Possible list Combinations: 28
# 7 0
# 25 0
# Height: 50.08          px2deg: 0.00389
# LON: -155.007       LAT:0.011
# Error (km)| H: 0.08Km    Lon:-0.13Km    Lat:-0.35Km
# ENU frame| xEast: 133.91m    yNorth:355.13m    zUp:75.22m
# Detection Time:0.42
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:9
# Number of total combinations:504
# Computational time: 0.01 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:8
# Number of total combinations:210
# Computational time: 0.01 s
# Mode:natural
# Computational time: 0.22 s
# Possible list Combinations: 35
# Computational time: 0.12 s
# Possible list Combinations: 4
# 3 0
# Height: 50.59          px2deg: 0.00393
# LON: -154.492       LAT:-0.028
# Error (km)| H: 0.59Km    Lon:0.32Km    Lat:0.82Km
# ENU frame| xEast: -326.03m    yNorth:-843.40m    zUp:590.30m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:12
# Number of total combinations:1320
# Computational time: 0.03 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:9
# Number of total combinations:336
# Computational time: 0.01 s
# Mode:natural
# Computational time: 0.37 s
# Possible list Combinations: 56
# Computational time: 0.21 s
# Possible list Combinations: 16
# 9 0
# Height: 50.65          px2deg: 0.00393
# LON: -153.970       LAT:-0.001
# Error (km)| H: 0.65Km    Lon:0.56Km    Lat:0.02Km
# ENU frame| xEast: -580.26m    yNorth:-19.14m    zUp:649.24m
# Detection Time:0.47
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:19
# Number of total combinations:5814
# Computational time: 0.10 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:12
# Number of total combinations:990
# Computational time: 0.02 s
# Mode:natural
# Computational time: 1.07 s
# Possible list Combinations: 165
# Computational time: 0.61 s
# Possible list Combinations: 79
# 5 0
# 18 0
# 19 0
# 23 0
# 25 0
# 26 0
# 29 0
# 35 0
# 37 0
# 37 1
# 44 0
# 49 0
# 53 1
# 67 1
# 78 1
# Height: 50.14          px2deg: 0.00390
# LON: -153.413       LAT:0.008
# Error (km)| H: 0.14Km    Lon:-0.27Km    Lat:-0.25Km
# ENU frame| xEast: 281.52m    yNorth:254.37m    zUp:144.64m
# Detection Time:0.46
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:17
# Number of total combinations:4080
# Computational time: 0.07 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:11
# Number of total combinations:720
# Computational time: 0.01 s
# Mode:natural
# Computational time: 0.79 s
# Possible list Combinations: 120
# Computational time: 0.44 s
# Possible list Combinations: 44
# 11 1
# 12 0
# 13 0
# 15 0
# 16 1
# 25 1
# Height: 50.29          px2deg: 0.00391
# LON: -152.890       LAT:-0.008
# Error (km)| H: 0.29Km    Lon:-0.07Km    Lat:0.23Km
# ENU frame| xEast: 69.85m    yNorth:-233.11m    zUp:291.50m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:19
# Number of total combinations:5814
# Computational time: 0.09 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:14
# Number of total combinations:1716
# Computational time: 0.03 s
# Mode:natural
# Computational time: 1.84 s
# Possible list Combinations: 286
# Computational time: 1.03 s
# Possible list Combinations: 115
# 4 0
# 6 0
# 29 0
# 31 0
# 32 0
# 33 0
# 34 0
# 39 0
# 40 0
# 41 0
# 45 0
# 46 0
# 50 0
# 59 0
# 71 1
# 79 0
# 109 1
# Height: 50.16          px2deg: 0.00390
# LON: -152.371       LAT:0.013
# Error (km)| H: 0.16Km    Lon:0.26Km    Lat:-0.41Km
# ENU frame| xEast: -271.33m    yNorth:421.07m    zUp:155.44m
# Detection Time:0.47
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:18
# Number of total combinations:4896
# Computational time: 0.08 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:16
# Number of total combinations:2730
# Computational time: 0.05 s
# Mode:natural
# Computational time: 2.82 s
# Possible list Combinations: 455
# Computational time: 1.59 s
# Possible list Combinations: 122
# 25 0
# 26 1
# 27 0
# 31 0
# 46 0
# 84 0
# 89 0
# 90 0
# 97 0
# 98 0
# 107 0
# 116 0
# 117 0
# 118 0
# 121 0
# Height: 50.49          px2deg: 0.00392
# LON: -151.829       LAT:0.015
# Error (km)| H: 0.49Km    Lon:-0.11Km    Lat:-0.47Km
# ENU frame| xEast: 117.54m    yNorth:482.92m    zUp:494.02m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:19
# Number of total combinations:5814
# Computational time: 0.09 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:16
# Number of total combinations:2730
# Computational time: 0.04 s
# Mode:natural
# Computational time: 2.82 s
# Possible list Combinations: 455
# Computational time: 1.60 s
# Possible list Combinations: 120
# 12 1
# 13 4
# 18 0
# 23 0
# 26 1
# 38 0
# 75 0
# 79 0
# 83 0
# 108 0
# Height: 50.53          px2deg: 0.00393
# LON: -151.318       LAT:0.023
# Error (km)| H: 0.53Km    Lon:0.45Km    Lat:-0.72Km
# ENU frame| xEast: -460.75m    yNorth:739.50m    zUp:526.79m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:15
# Number of total combinations:2730
# Computational time: 0.04 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:17
# Number of total combinations:3360
# Computational time: 0.05 s
# Mode:inverse
# Computational time: 2.80 s
# Possible list Combinations: 455
# Computational time: 1.60 s
# Possible list Combinations: 64
# 0 0
# 5 0
# 6 0
# 22 0
# 34 0
# 46 0
# Height: 50.84          px2deg: 0.00395
# LON: -150.785       LAT:0.016
# Error (km)| H: 0.84Km    Lon:0.36Km    Lat:-0.52Km
# ENU frame| xEast: -372.97m    yNorth:531.20m    zUp:838.14m
# Detection Time:0.44
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:19
# Number of total combinations:5814
# Computational time: 0.09 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:17
# Number of total combinations:3360
# Computational time: 0.05 s
# Mode:natural
# Computational time: 3.51 s
# Possible list Combinations: 560
# Computational time: 1.99 s
# Possible list Combinations: 120
# 0 0
# 2 0
# 8 0
# 9 0
# 17 0
# 19 0
# 20 0
# 34 0
# 70 0
# 71 0
# 72 0
# 74 0
# 75 0
# 102 0
# 105 0
# 113 1
# Height: 51.28          px2deg: 0.00398
# LON: -150.270       LAT:0.022
# Error (km)| H: 1.28Km    Lon:0.79Km    Lat:-0.69Km
# ENU frame| xEast: -817.63m    yNorth:709.25m    zUp:1284.09m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:15
# Number of total combinations:2730
# Computational time: 0.04 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:17
# Number of total combinations:3360
# Computational time: 0.06 s
# Mode:inverse
# Computational time: 2.84 s
# Possible list Combinations: 455
# Computational time: 1.73 s
# Possible list Combinations: 86
# 3 0
# 7 0
# 8 1
# 9 1
# 16 0
# 17 0
# 18 0
# 19 0
# 51 1
# 57 0
# 59 0
# 70 0
# 79 0
# 82 1
# Height: 50.41          px2deg: 0.00392
# LON: -149.718       LAT:0.013
# Error (km)| H: 0.41Km    Lon:0.12Km    Lat:-0.43Km
# ENU frame| xEast: -122.48m    yNorth:439.22m    zUp:408.39m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:10
# Number of total combinations:720
# Computational time: 0.01 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:12
# Number of total combinations:990
# Computational time: 0.02 s
# Mode:inverse
# Computational time: 0.75 s
# Possible list Combinations: 120
# Computational time: 0.42 s
# Possible list Combinations: 10
# 5 0
# 8 0
# Height: 53.14          px2deg: 0.00413
# LON: -149.191       LAT:0.060
# Error (km)| H: 3.14Km    Lon:0.21Km    Lat:-1.83Km
# ENU frame| xEast: -211.96m    yNorth:1886.15m    zUp:3137.19m
# Detection Time:0.43
#
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
#
#
# Total craters founded:13
# Number of total combinations:1716
# Computational time: 0.03 s
#  |████████████████████████████████████████████████████████████████████████████████████████████████████| 100.0%
# Total craters catalogued:13
# Number of total combinations:1320
# Computational time: 0.02 s
# Mode:natural
# Computational time: 1.37 s
# Possible list Combinations: 220
# Computational time: 0.78 s
# Possible list Combinations: 20
# Association was not possible...
# Association was not possible...
# Sorry, cannot find matches...
# Done!

# %%
FILE = pd.read_csv('Pos_Err_d100_quartile_40-60_HL.csv')

# %%
H, Lon, Lat, IDXs = FILE['Error_H(km)'], FILE['Error_LON(km)'], FILE['Error_LAT(km)'], FILE['ID']

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, H, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Altitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, H, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,2])
plt.title('Altitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('AltitudeError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, H, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Altitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, H, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,2])
plt.title('Altitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('AltitudeError_d=100_quartile_40-60B.jpg')
plt.show()

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, Lon, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Longitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, Lon, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,1])
plt.title('Longitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('LongError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, Lon, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Longitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, Lon, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,1])
plt.title('Longitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('LongError_d=100_quartile_40-60B.jpg')
plt.show()

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, Lat, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Latitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, Lat, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,1])
plt.title('Latitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('LatError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, Lat, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.title('Latitude Error')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, Lat, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('Km')
plt.ylim([0,1])
plt.title('Latitude Error')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('LatError_d=100_quartile_40-60B.jpg')
plt.show()

# %%
xEast, yNorth, zUp = FILE['xEast'], FILE['yNorth'], FILE['zUp']

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, xEast, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('East')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, xEast, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1000])
plt.title('East')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('EastError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, xEast, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('East')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, xEast, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1000])
plt.title('East')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('EastError_d=100_quartile_40-60B.jpg')
plt.show()

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('North')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1000])
plt.title('North')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('NorthError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('North')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1000])
plt.title('North')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('NorthError_d=100_quartile_40-60B.jpg')
plt.show()

# %%
plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, zUp, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('Up')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([0,end//2])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1500])
plt.title('Up')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335,:Img.shape[1]//2])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'-147°',f'{-147+18}°',f'{-147+2*18}°',f'{-147+3*18}°',f'{-147+4*18}°',f'{-147+5*18}°',f'{-147+6*18}°',f'{-147+7*18}°',f'{-147+8*18}°',f'{-147+9*18}°',f'{-147+18*10}°'])
plt.savefig('UpError_d=100_quartile_40-60A.jpg')
plt.show()


plt.figure(dpi=150, figsize=(10,6), tight_layout=True)
end = len(IDXs)
plt.subplot(311)
plt.scatter(IDXs, zUp, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.title('Up')
plt.show()

plt.subplot(312)
plt.scatter(IDXs, yNorth, s =2)
plt.xlim([end//2, end])
plt.xlabel('idx')
plt.ylabel('m')
plt.ylim([0,1500])
plt.title('Up')

plt.subplot(313)
Img = cv2.imread('4.bmp')
plt.imshow(Img[235:335, Img.shape[1]//2: ])
plt.yticks([0,50,100],[f'5°',f'0°',f'-5°'])
plt.xticks([0,int(1665/20),int(1665/20*2),int(1665/20*3),int(1665/20*4),int(1665/20*5),int(1665/20*6),int(1665/20*7),int(1665/20*8),int(1665/20*9),1665//2],[f'{-147+18*10}°',f'{-147+18*11}°',f'{-147+18*12}°',f'{-147+18*13}°',f'{-147+18*14}°',f'{-147+18*15}°',f'{-147+18*16}°',f'{-147+18*17}°',f'{-147+18*18}°',f'{-180+15}°',f'{-147}°'])
plt.savefig('UpError_d=100_quartile_40-60B.jpg')
plt.show()
